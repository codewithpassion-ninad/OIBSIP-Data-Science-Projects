# %% [markdown]
# **OASIS INFOBYTE INTERNSHIP - AUGUST - SEPT 2023**\
# **NINAD NILESH SUGANDHI**\
# **IRIS CLASSIFICATION**

# %% [markdown]
# **Importing all necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
import datetime as dt
import calendar
import warnings
import plotly.express as px

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# **Printing the current version of all libraries used**

# %%
print('''Pandas version is: {0}
Numpy version is: {1}
Matplotlib version is: {2}
Seaborn version is: {3}'''.format(pd.__version__, np.__version__, matplotlib.__version__, sns.__version__))
# Out:
# Pandas version is: 1.5.3
# Numpy version is: 1.23.5
# Matplotlib version is: 3.7.0
# Seaborn version is: 0.12.2

# %% [markdown]
# **Loading Data**\
# *Printing first and last few entries of data*

# %%
df = pd.read_csv("D:\\NINAD SUGANDHI\\GOOGLE COLAB\\OASIS INFOBYTE PROJECTS\\Unemployment rate upto 11-20.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
# 5  Andhra Pradesh   30-06-2020          M                              3.31
# 6  Andhra Pradesh   31-07-2020          M                              8.34
# 7  Andhra Pradesh   31-08-2020          M                              6.96
# 8  Andhra Pradesh   30-09-2020          M                              6.40
# 9  Andhra Pradesh   31-10-2020          M                              6.59
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# ...

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %%
df.tail(10)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 257  West Bengal   31-01-2020          M                              6.94
# 258  West Bengal   29-02-2020          M                              4.92
# 259  West Bengal   31-03-2020          M                              6.92
# 260  West Bengal   30-04-2020          M                             17.41
# 261  West Bengal   31-05-2020          M                             17.41
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 262   False  False       False                             False
# 263   False  False       False                             False
# 264   False  False       False                             False
# 265   False  False       False                             False
# 266   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  \
# 0                  False                                     False     False
# ...

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df.size
# Out:
# 2403

# %%
df.shape
# Out:
# (267, 9)

# %%
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Region.1                                     object
# longitude                                   float64
# latitude                                    float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
description = df.describe().T.style.background_gradient(
    cmap='viridis',  # Choose a colormap of your preference
    low=0, high=1,   # Set the range of colors for the gradient
    axis=None        # Apply the gradient across the entire DataFrame
)

# Add more styling attributes
styled_description = description.set_properties(**{'font-size': '10pt', 'text-align': 'center'}).bar(subset=['mean'], color='#FFA07A')  # Customize the bar color for mean values
styled_description
# Out:
# <style type="text/css">
# #T_a045c_row0_col0, #T_a045c_row0_col2, #T_a045c_row0_col3, #T_a045c_row0_col4, #T_a045c_row0_col5, #T_a045c_row0_col6, #T_a045c_row0_col7, #T_a045c_row1_col0, #T_a045c_row1_col3, #T_a045c_row2_col0, #T_a045c_row2_col2, #T_a045c_row2_col3, #T_a045c_row2_col4, #T_a045c_row2_col5, #T_a045c_row2_col6, #T_a045c_row2_col7, #T_a045c_row3_col0, #T_a045c_row3_col2, #T_a045c_row3_col3, #T_a045c_row3_col4, #T_a045c_row3_col5, #T_a045c_row3_col6, #T_a045c_row3_col7, #T_a045c_row4_col0, #T_a045c_row4_col2, #T_a045c_row4_col3, #T_a045c_row4_col4, #T_a045c_row4_col5, #T_a045c_row4_col6, #T_a045c_row4_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
# }
# #T_a045c_row0_col1, #T_a045c_row2_col1, #T_a045c_row3_col1, #T_a045c_row4_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 10pt;
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #FFA07A 0.0%, transparent 0.0%);
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=267, step=1)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.columns = ['region', 'date', 'frequency', 'est_unemp_rate', 'est_emp', 'est_lab_part_rate', 'region1', 'longitude', 'latitude']
df.columns
# Out:
# ['region',
#  'date',
#  'frequency',
#  'est_unemp_rate',
#  'est_emp',
#  'est_lab_part_rate',
#  'region1',
#  'longitude',
#  'latitude']

# %% [markdown]
# **Data Visualizations**\
# Several Techniques used for visualizations are:\
# Pair Plot\
# Count plot\
# Hist plot\
# Dist plot\
# Heatmap\
# Box plot\
# Voilin Plot\
# Swarm Plot\
# Bar Plot\
# Pie Chart\
# Sunburst Plot\
# Geographical Scatter Plot

# %%
sns.pairplot(df)

# %%
sns.histplot(data=df, x='est_unemp_rate', bins=20, kde=True)
# Out:
# <Axes: xlabel='est_unemp_rate', ylabel='Count'>

# %%
sns.distplot(df['latitude'])
# Out:
# <Axes: xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(df['longitude'])
# Out:
# <Axes: xlabel='longitude', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='latitude',data=df,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Distribution of number of unemployed people as per the latitude',size=20)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x='longitude',data=df,palette='bright')
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
plt.title('Distribution of number of unemployed people as per the longitude',size=20)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='viridis', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['est_unemp_rate', 'est_emp', 'est_lab_part_rate']])
plt.title("Box Plot of Employment Data")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %%
sns.pairplot(df[['est_unemp_rate', 'est_emp', 'est_lab_part_rate']])
plt.title("Pairwise Scatter Plot")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='frequency', y='est_unemp_rate', data=df)
plt.title("Violin Plot of Employment Rate by Frequency")
plt.xlabel("Frequency")
plt.ylabel("Estimated Unemployment Rate")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='region', y='est_unemp_rate', data=df)
plt.title("Average Estimated Unemployment Rate by Region")
plt.xlabel("Region")
plt.ylabel("Average Estimated Unemployment Rate")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='region', y='est_unemp_rate', data=df, inner=None)
sns.swarmplot(x='region', y='est_unemp_rate', data=df, color='k', alpha=0.7)
plt.title("Distribution of Estimated Unemployment Rate by Region")
plt.xlabel("Region")
plt.ylabel("Estimated Unemployment Rate")
plt.xticks(rotation=60)
plt.show()

# %%
avg_emp_by_state = df.groupby('region')['est_emp'].mean()

plt.figure(figsize=(8, 8))
plt.pie(avg_emp_by_state, labels=avg_emp_by_state.index, autopct='%1.1f%%', startangle=140)
plt.title("Average Employment Rate by State")
plt.show()

# %%
fig = px.sunburst(df, path=['region1', 'region'], values='est_emp')
fig.update_layout(title="Sunburst Plot of Employment by Region and Subregion", width=1200, height=600)
fig.show()

# %%
fig = px.scatter_geo(df, 'latitude', 'longitude', scope='asia', hover_name='region', color = 'region', size = 'est_unemp_rate', animation_frame='Month')
fig.update_layout(title="Geographic Scatter Plot of Impact of Pandemic in India")
fig.update_geos(lataxis_range=[5,35], lonaxis_range=[65, 100], showocean=True)
fig.show()

# %%
df['date'] = pd.to_datetime(df['date'])

# Extract the month from the 'date' column and create a new column 'month'
df['Month'] = df['date'].dt.month

# Calculate the average unemployment rates before and after pandemic
avg_unemp_before_pandemic = df[(df['Month'] >= 1) & (df['Month'] <= 4)]['est_unemp_rate'].mean()
avg_unemp_after_pandemic = df[(df['Month'] >4) & (df['Month'] <=12)]['est_unemp_rate'].mean()

print("Average Unemployment Rate Before Pandemic:", avg_unemp_before_pandemic)
print("Average Unemployment Rate After Pandemic:", avg_unemp_after_pandemic)
# Out:
# Average Unemployment Rate Before Pandemic: 12.85047619047619
# Average Unemployment Rate After Pandemic: 11.83925925925926

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df, x='region1', y='est_unemp_rate', hue='year', ci=None, palette = ["#e60049"])
plt.title("Effect of Pandemic on Unemployment Rates by Region")
plt.xlabel("Region1")
plt.ylabel("Unemployment Rate")
plt.legend(title="Year", loc='upper left', labels=['After 2020'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='region', y='est_unemp_rate', hue='year', ci=None, palette=["#00ffff"])
plt.title("Effect of Pandemic on Unemployment Rates by States")
plt.xlabel("Region1")
plt.ylabel("Unemployment Rate")
plt.legend(title="Year", loc='upper left', labels=['After 2020'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=['Before Pandemic', 'After Pandemic'], y=[avg_unemp_before_pandemic, avg_unemp_after_pandemic])
plt.title("Average Unemployment Rate Comparison (Before and After Pandemic)")
plt.ylabel("Average Unemployment Rate")
plt.show()
